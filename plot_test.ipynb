# %%
using Plots
x,y=rand(300),rand(300)
for i in 2:length(x)     #ランダムウォーク"的"に適当に動いてもらいます
    x[i]=x[i-1]+x[i]-0.5
    y[i]=y[i-1]+y[i]-0.5
end

# %%
@gif for i in 1:length(x)
    scatter([x[i]],[y[i]],legend=:none,lims=(-5,5),size=(250,250))
end
# Out:
# ┌ Info: Saved animation to
# │   fn = C:\Users\JUN\Documents\Julia_notebook\tmp.gif
# └ @ Plots C:\Users\JUN\.julia\packages\Plots\qZHsp\src\animation.jl:98
# Plots.AnimatedGif("C:\\Users\\JUN\\Documents\\Julia_notebook\\tmp.gif")

# %%
for i in 1:length(x)
    IJulia.clear_output(true)
    scatter([x[i]],[y[i]],legend=:none,lims=(-5,5),size=(250,250))|>display
end

# %%
anim = @animate for i in 1:length(x)
    IJulia.clear_output(true)
    scatter([x[i]],[y[i]],legend=:none,lims=(-5,5),size=(250,250))|>display
end
# Out:
# Animation("C:\\Users\\JUN\\AppData\\Local\\Temp\\jl_yOdc47", ["000001.png", "000002.png", "000003.png", "000004.png", "000005.png", "000006.png", "000007.png", "000008.png", "000009.png", "000010.png"  …  "000291.png", "000292.png", "000293.png", "000294.png", "000295.png", "000296.png", "000297.png", "000298.png", "000299.png", "000300.png"])

# %%
gif(anim,fps=30)
# Out:
# ┌ Info: Saved animation to
# │   fn = C:\Users\JUN\Documents\Julia_notebook\tmp.gif
# └ @ Plots C:\Users\JUN\.julia\packages\Plots\qZHsp\src\animation.jl:98
# Plots.AnimatedGif("C:\\Users\\JUN\\Documents\\Julia_notebook\\tmp.gif")
